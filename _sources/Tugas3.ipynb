# %% [markdown]
# # Tugas 3 - Crawling Data Berita Online

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd
#agent user : supaya web server menampilkan konten yang dimiliki sesuai dengan OS yang kita gunakan, jadi web server tau browser dan OS yang kita gunakan
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}

# %%
#membuat function scraping data web
def scrape_detik(page):
  global hades  
  data = []
  for p in range(1,page+1):
    url = f"https://www.detik.com/search/searchall?query=pemilu+2024&siteid=2&sortby=time&page={p}"
    request =  req.get(url,hades).text
    #var bs yang menyimpan data request
    soup = bs(request, 'lxml')
    news_list = soup.find('div', 'list media_rows list-berita')
    news_article = news_list.find_all('article')
    for x in news_article:
      link=x.find_all('h2')
      link = [ele.text.strip() for ele in link]
      content=x.find_all('p')
      content = [ele.text.strip() for ele in content]
      data.append([link[0],content[0]])
  return data

news=scrape_detik(7)
news_result = pd.DataFrame(news,columns =['Judul','Isi'])
news_result
# Out:
#                                                 Judul  \
# 0   Gibran soal Kriteria Cagub Jateng PDIP Versi B...
# 1   Anies Merosot di Survei Litbang Kompas, NasDem...
# 2   Bambang Pacul Beber Kriteria Cagub Jateng Peng...
# 3   AHY Suguhkan Masakan Spesial Favorit Paloh di ...
# 4   Cegah Pencurian Data Pemilih, Bawaslu dan BSSN...
# ..                                                ...
# 58  Crazy Rich Surabaya Tom Liwafa Beber Alasan Ba...
# 59                      Tata Kelola Pengawasan Pemilu
# 60  Prediksi Serangan Siber Naik Jelang Pemilu, BS...
# 61  Tangkal Serangan Siber di Pemilu, BSSN: Satgas...
# 62  Bawaslu Awasi Hak Kelompok Disabilitas untuk M...
#
#                                                   Isi
# 0   Wali Kota Solo Gibran Rakabuming yang siap maj...
# 1   Survei Litbang Kompas menunjukkan elektabilita...
# 2   Ketua DPD PDIP Jawa Tengah, Bambang Wuryanto a...
# 3   Surya Paloh menyambangi DPP Partai Demokrat un...
# 4   Bawaslu RI dan BSSN membentuk tim keamanan sib...
# ..                                                ...
# 58  Crazy Rich asal Surabaya, Tom Liwafa resmi mas...
# 59  Ritme keserentakan pemilu yang dinamis membutu...
# 60  Badan Siber dan Sandi Negara (BSSN) memprediks...
# 61  Kepala Badan Siber dan Sandi Negara (BSSN), Hi...
# 62  Bawaslu akan mengawasi hak kelompok disabilita...
#
# [63 rows x 2 columns]

# %%
news_result.to_csv('news.csv')
